# %% [markdown]
# # Data & Artificial Intelligence
#
# Catarina Rilhó r0943545
#
#
# Academic year 2022-2023
#
# ## 1 Assigment

# %% [markdown]
# Business Understanding
#
# Assessments - Informations about assessments of the students.
#
# •	code_module – identification code of the module
# •	code_presentation - identification code of the presentation
# •	id_assessment – identification number of the assessment
# •	assessment_type – type of assessment. Three types of assessments exist: Tutor Marked Assessment (TMA), Computer Marked Assessment (CMA) and Final Exam (Exam).
# •	date – information about the final submission date of the assessment
# •	Weight – weight of the assessment in %. Typically, Exams are treated separately and have the weight 100%; the sum of all other assessments is 100%.
#
# Courses - Informations about the courses that students have, and how they work.
# •	code_module – code name of the module, which serves as the identifier
# •	code_presentation – code name of the presentation. It consists of the year and “B” for the presentation starting in February and “J” for the presentation starting in October.
# •	module_presentation_length - length of the module-presentation in days
#
# StudentAssessment - Informations about student's assessments like their results.
# •	code_module – an identification code for a module
# •	code_presentation - the identification code of the presentation
# •	id_student – a unique identification number for the student
# •	date_registration – the date of student’s registration on the module presentation
# •	date_unregistration – date of student unregistration from the module presentation
#
# StudentRegistration- Informations about the registration of the students. Even when the students doesn't registered, the time of unregistered is also recorded.
# •	code_module – an identification code for a module
# •	code_presentation - the identification code of the presentation
# •	id_student – a unique identification number for the student
# •	date_registration – the date of student’s registration on the module presentation
# •	date_unregistration – date of student unregistration from the module presentation
#
# StudentInfo - Informations about the students and their results.
# •	code_module – an identification code for a module
# •	code_presentation - the identification code of the presentation
# •	id_student – a unique identification number for the student
# •	gender – the student’s gender
# •	region – identifies the geographic region
# •	highest_education – highest student education level on entry to the module presentation
# •	imd_band – specifies the Index of Multiple Depravation band of the place where the student lived during the module-presentation.
# •	age_band – band of the student’s age
# •	num_of_prev_attempts – the number times the student has attempted this module
# •	studied_credits – the total number of credits for the modules the student is currently studying
# •	disability – indicates whether the student has declared a disability
# •	final_result – student’s final result in the module-presentation
#
# StudentVle -Information about student's interections with the material available in virtual learning environment.
# •	code_module – an identification code for a module
# •	code_presentation - the identification code of the module presentation
# •	id_student – a unique identification number for the student
# •	id_site - an identification number for the VLE material
# •	date – the date of student’s interaction with the material
# •	sum_click – the number of times a student interacts with the material on that date
#
# Vle - Information about the materials that are available in the virtual learning environment.
# •	id_site – an identification number of the material
# •	code_module – an identification code for module
# •	code_presentation - the identification code of presentation
# •	activity_type – the role associated with the module material
# •	week_from – the week from which the material is planned to be used
# •	week_to – week until which the material is planned to be used

# %% [markdown]
# Assessments - Informations about assessments of the students.
#
# •	code_module – identification code of the module
# •	code_presentation - identification code of the presentation
# •	id_assessment – identification number of the assessment
# •	assessment_type – type of assessment. Three types of assessments exist: Tutor Marked Assessment (TMA), Computer Marked Assessment (CMA) and Final Exam (Exam).
# •	date – information about the final submission date of the assessment
# •	Weight – weight of the assessment in %. Typically, Exams are treated separately and have the weight 100%; the sum of all other assessments is 100%.

# %%
import os 
import pandas as pd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
plt.rcParams["axes.labelsize"] = 18
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
os.chdir('C:/Users/Catar/Downloads/DAI_Assignment1_dataset/assignment data')

# %% [markdown]
# ### Assessments

# %%
assessments = pd.read_csv('assessments.csv')
assessments.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type  date  weight
# 0         AAA             2013J           1752             TMA   NaN    10.0
# 1         AAA             2013J           1753             TMA   NaN    20.0
# 2         AAA             2013J           1754             TMA   NaN    20.0
# 3         AAA             2013J           1755             TMA   NaN    20.0
# 4         AAA             2013J           1756             TMA   NaN    30.0

# %%
#Do the assessments have missing values?
assessments.isnull().sum()

#Let's see why!
# Out:
# code_module            0
# code_presentation      0
# id_assessment          0
# assessment_type        0
# date                 114
# weight                 0
# dtype: int64

# %%
#Replace the missing values
values= {"date": "NotSubmited"}
assessments = assessments.fillna(values)
assessments
# Out:
#     code_module code_presentation  id_assessment assessment_type         date  \
# 0           AAA             2013J           1752             TMA  NotSubmited
# 1           AAA             2013J           1753             TMA  NotSubmited
# 2           AAA             2013J           1754             TMA  NotSubmited
# 3           AAA             2013J           1755             TMA  NotSubmited
# 4           AAA             2013J           1756             TMA  NotSubmited
# ..          ...               ...            ...             ...          ...
# 201         GGG             2014J          37443             CMA        229.0
# 202         GGG             2014J          37435             TMA  NotSubmited
# 203         GGG             2014J          37436             TMA        124.0
# 204         GGG             2014J          37437             TMA        173.0
# 205         GGG             2014J          37444            Exam  NotSubmited
#
#      weight
# 0      10.0
# ...

# %%
#To be more clear, I have replaced the missing values to "NotSubmited", and that way as we can see, there are not going to have missing values anymore.
assessments.isnull().sum()
# Out:
# code_module          0
# code_presentation    0
# id_assessment        0
# assessment_type      0
# date                 0
# weight               0
# dtype: int64

# %%
#How many assessments do the students have for each type?
assessments['assessment_type'].value_counts()
# Out:
# TMA     106
# CMA      76
# Exam     24
# Name: assessment_type, dtype: int64

# %%
#How many assessments do the students have for each type?
assessments["assessment_type"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
assessments['date'].value_counts()
# Out:
# NotSubmited    114
# 222.0            8
# 227.0            5
# 166.0            4
# 229.0            4
# 241.0            4
# 47.0             4
# 200.0            3
# 68.0             3
# 117.0            3
# 25.0             3
# 131.0            3
# 124.0            3
# 207.0            2
# 236.0            2
# 18.0             2
# 53.0             2
# 19.0             2
# 195.0            1
# 33.0             1
# 208.0            1
# 235.0            1
# 89.0             1
# 194.0            1
# 159.0            1
# 111.0            1
# 87.0             1
# 24.0             1
# 52.0             1
# 94.0             1
# 136.0            1
# 61.0             1
# 215.0            1
# 146.0            1
# 261.0            1
# 74.0             1
# 12.0             1
# 54.0             1
# 201.0            1
# 137.0            1
# 32.0             1
# 96.0             1
# 67.0             1
# 109.0            1
# 158.0            1
# 79.0             1
# 149.0            1
# ...

# %%
#For each type of assessments, how many weren't submited?
assessments.groupby("assessment_type")["date"].describe()
# Out:
#                 count unique          top freq
# assessment_type
# CMA                76     20  NotSubmited   41
# Exam               24      6  NotSubmited   18
# TMA               106     36  NotSubmited   55

# %% [markdown]
# As we can see here, there's a direct relation between the missing values on the date and the type of assessments that the students have during the module. So, i got the conclusion that, of 106 values of TMA, there were 55 that weren're submited at all, wich means that 51,8% of the assessments TMA doesn't have a date of submission. That let us believe that this kind of assessment could not be productive to the students, since more than half doesn't submit them. The same thing happen on CMA and Exam.

# %% [markdown]
# ### Courses

# %%
courses = pd.read_csv('courses.csv')
courses.head()
# Out:
#   code_module code_presentation  module_presentation_length
# 0         AAA             2113J                         268
# 1         AAA             2014J                         269
# 2         BBB             2113J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240

# %%
coursesPerDayLength = courses.groupby("code_module")["module_presentation_length"].count()
coursesPerDayLength
# Out:
# code_module
# AAA    2
# BBB    4
# CCC    2
# DDD    4
# EEE    3
# FFF    4
# GGG    3
# Name: module_presentation_length, dtype: int64

# %%
#Combining this two variables, we can see the length of the courses. As we can see the module "AAA", it's 2 days, but the legth of the "BBB" it's 4 days. This information could be usefull since we can see wich one of this courses take a lot effort for the students seeing how much is the lenght.

# %%
#How many courses do the students have?
courses["code_presentation"].value_counts()
# Out:
# 2014J    7
# 2113J    6
# 2014B    6
# 2013B    3
# Name: code_presentation, dtype: int64

# %%
#As we can see, during the month of february students will have 9 presentations. Comparing to october, students are going to have a lot less module presentations.

# %% [markdown]
# ### Student Assessment

# %%
studentAssessment = pd.read_csv('studentAssessment.csv')
studentAssessment.head()
# Out:
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0

# %%
studentAssessment.value_counts()
# Out:
# id_assessment  id_student  date_submitted  is_banked  score
# 1752           11391       18              0          78.0     1
# 34871          1464952     213             0          76.0     1
#                1097354     223             0          80.0     1
#                1118284     207             0          94.0     1
#                1337055     199             0          83.0     1
#                                                               ..
# 24294          693182      207             0          52.0     1
#                693204      207             0          59.0     1
#                693302      199             0          88.0     1
#                693747      207             0          73.0     1
# 37443          2648187     215             0          80.0     1
# Length: 173739, dtype: int64

# %%
#How many students get the same grade?
studentAssessment["score"].value_counts()
# Out:
# 100.0    18813
# 80.0     12109
# 60.0      5620
# 78.0      4504
# 90.0      4368
#          ...
# 4.0         28
# 5.0         25
# 7.0         24
# 3.0         17
# 2.0         12
# Name: score, Length: 101, dtype: int64

# %%
#This command can show us that there was so much more score of "100.00" than "2.0". Confronting those numbers, we can have the information that there are more students that have great grades with "distinction" than worst grades.

# %%
#Does exists any missing values on StudentAssessments?
studentAssessment.isnull().sum()
# Out:
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64

# %%
#How many students have passed their assessments (Have a score > 50.0)?
scoresOver50 = studentAssessment[studentAssessment['score'] >= 50.0]
scoresOver50.sort_values(['score'],ascending=True)
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 72564           25343      525762              81          0   50.0
# 70323           25341     2353766              25          0   50.0
# 43209           15022      686378             110          0   50.0
# 53662           24290      555604             234          0   50.0
# 63376           24298      480115             219          0   50.0
# ...               ...         ...             ...        ...    ...
# 28093           15007      530487             210          0  100.0
# 28089           15007      527580             210          0  100.0
# 10636           14992     2244724              95          0  100.0
# 10634           14992     2231614              95          0  100.0
# 137321          34891      552395              -1          1  100.0
#
# [158431 rows x 5 columns]

# %%
#How many students had their grades better than 50.0?
scoresOver50.value_counts().sum()
# Out:
# 158431

# %%
#How many students had their grades worst than 50.0?
scoresDown50= studentAssessment[studentAssessment['score'] <= 50.0]
scoresDown50.sort_values(['score'],ascending=True)
# Out:
#         id_assessment  id_student  date_submitted  is_banked  score
# 93392           25366      646952             146          0    0.0
# 59792           24295      630891              21          0    0.0
# 9693            14991      406311              60          0    0.0
# 60005           24295      651267              26          0    0.0
# 60019           24295      652994              21          0    0.0
# ...               ...         ...             ...        ...    ...
# 81605           25352     2627449             163          0   50.0
# 81634           25353     1678800             207          0   50.0
# 156181          34908      429832             242          0   50.0
# 86497           25359     2261142             158          0   50.0
# 128511          34881      594855             227          0   50.0
#
# [16945 rows x 5 columns]

# %%
scoresDown50.value_counts().sum()
# Out:
# 16945

# %%
#As we can see, there we're much more students that had grades better than 50, wich means, there were a lot a students having a positives grandes than negative. That way, we can see that the students are having a really postive performance, since 158431 had scores higher than 50.0, and only 16945 had lower than that.

# %% [markdown]
# ### Student Info

# %%
studentInfo = pd.read_csv('studentInfo.csv')
studentInfo.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         NaN               NaN       28400    NaN              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1                    NaN   20-30%      NaN                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
#Does exists any missing values at StudentInfo?
studentInfo.isnull().sum()
# Out:
# code_module             3446
# code_presentation       3446
# id_student                 0
# gender                  3446
# region                     0
# highest_education       3446
# imd_band                1111
# age_band                3446
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %%
values= {"age_band": "Unknown"}
studentInfo = studentInfo.fillna(values)
studentInfo
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             NaN               NaN       28400    NaN              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# ...           ...               ...         ...    ...                   ...
# 32588         GGG             2014J     2640965      F                 Wales
# 32589         GGG             2014J     2645731      F   East Anglian Region
# 32590         GGG             2014J     2648187      F          South Region
# 32591         GGG             2014J     2679821      F     South East Region
# 32592         GGG             2014J     2684003      F      Yorkshire Region
#
# ...

# %%
dropHigher = studentInfo.drop("highest_education", axis=1)
y = studentInfo["highest_education"]
#Since there's a lot of missing values on the highest education column i assume that this column wouldn't be necessary to explain the values, so i dropped it. That way we can start "cleaning" the data and focus on what is really important.

# %%
#Right now, i'm going to inspect the conditions of the students that passed on the final results. That way we can find a target of the students that have good grades and see if there's anything in comun between then.

# %%
#How many students fail their assessments?
studentFail = studentInfo[studentInfo['final_result'] == "Fail" ]
studentFail.head()
# Out:
#    code_module code_presentation  id_student gender                region  \
# 18         AAA             2013J       74372      M   East Anglian Region
# 52         AAA             2013J      146188      F  West Midlands Region
# 53         AAA             2013J      147756      M          North Region
# 70         AAA             2013J      175991      F  North Western Region
# 76         AAA             2013J      185439      M         London Region
#
#         highest_education imd_band age_band  num_of_prev_attempts  \
# 18  A Level or Equivalent    10-20    35-55                     0
# 52  A Level or Equivalent   20-30%     0-35                     0
# 53     Lower Than A Level   60-70%     0-35                     0
# 70  A Level or Equivalent   80-90%     0-35                     0
# 76       HE Qualification    10-20     0-35                     0
#
#     studied_credits disability final_result
# 18              150          N         Fail
# ...

# %%
studentFail.value_counts().sum()
# Out:
# 6058

# %%
#As we can see, there were 6058 that fail their assessments on the final results.

# %%
studentPass = studentInfo[studentInfo['final_result'] == "Pass" ]
studentPass.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         NaN               NaN       28400    NaN              Scotland
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
# 5         AAA             2013J       38053      M                 Wales
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1                    NaN   20-30%  Unknown                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
# 5  A Level or Equivalent   80-90%    35-55                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
studentPass.value_counts().sum()
# Out:
# 10473

# %%
#There were 10473 students that passed on the final results. Comparing to the number of students that failed we can see that there were many students that have a positive classification.

# %%
studentInfo["region"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
#Does the region affects the final results of the students?
studentRegion = studentInfo["region"]
studentRegion
# Out:
# 0         East Anglian Region
# 1                    Scotland
# 2        North Western Region
# 3           South East Region
# 4        West Midlands Region
#                  ...
# 32588                   Wales
# 32589     East Anglian Region
# 32590            South Region
# 32591       South East Region
# 32592        Yorkshire Region
# Name: region, Length: 32593, dtype: object

# %%
regionStudent = studentInfo.groupby("region")["final_result"].value_counts()
regionStudent.head()
# Out:
# region                final_result
# East Anglian Region   Pass            1309
#                       Withdrawn       1006
#                       Fail             698
#                       Distinction      327
# East Midlands Region  Pass             881
# Name: final_result, dtype: int64

# %%
regionStudent = studentInfo.groupby("region")["final_result"].value_counts()
regionStudent.plot.bar(figsize=(8,8))
# Out:
# <AxesSubplot:xlabel='region,final_result'>

# %%
#First lets see how many students are in general from Wales
studentFromWales = studentInfo[studentInfo['region']=='Wales']
studentFromWales.value_counts().sum()
# Out:
# 2086

# %%
studentWalesFails = studentInfo[(studentInfo['final_result']=='Fail') & (studentInfo['region']=='Wales')]
studentWalesFails.head()
# Out:
#     code_module code_presentation  id_student gender region  \
# 117         AAA             2013J      281250      M  Wales
# 178         AAA             2013J      368824      M  Wales
# 409         AAA             2014J      111512      M  Wales
# 439         AAA             2014J      165226      F  Wales
# 492         AAA             2014J      294655      M  Wales
#
#          highest_education imd_band age_band  num_of_prev_attempts  \
# 117     Lower Than A Level   70-80%    35-55                     0
# 178       HE Qualification   50-60%    35-55                     0
# 409  A Level or Equivalent   40-50%     0-35                     0
# 439  A Level or Equivalent   30-40%     0-35                     0
# 492  A Level or Equivalent   70-80%    35-55                     0
#
#      studied_credits disability final_result
# 117               60          N         Fail
# 178              120          N         Fail
# 409               60          N         Fail
# ...

# %%
#How many students have failed their final result?
studentWalesFails.value_counts().sum()
# Out:
# 620

# %%
#From all the students from Wales (2086) there were 620 students that failed their module presentation, wich gives this region 29.7% of failness.

# %%
#North Western Region
studentNorthWesternRegion = studentInfo[studentInfo['region']=='North Western Region']
studentNorthWesternRegion.value_counts().sum()
# Out:
# 2901

# %%
studentNorthWesternRegionFail = studentInfo[(studentInfo['final_result']=='Fail') & (studentInfo['region']=='North Western Region')]
studentNorthWesternRegionFail.head()
# Out:
#     code_module code_presentation  id_student gender                region  \
# 70          AAA             2013J      175991      F  North Western Region
# 118         AAA             2013J      281589      M  North Western Region
# 134         AAA             2013J      305152      M  North Western Region
# 286         AAA             2013J     2164705      F  North Western Region
# 673         AAA             2014J     2045084      M  North Western Region
#
#          highest_education imd_band age_band  num_of_prev_attempts  \
# 70   A Level or Equivalent   80-90%     0-35                     0
# 118       HE Qualification   30-40%     0-35                     0
# 134  A Level or Equivalent   70-80%     0-35                     0
# 286  A Level or Equivalent   40-50%     0-35                     0
# 673       HE Qualification   40-50%    35-55                     0
#
#      studied_credits disability final_result
# 70               180          N         Fail
# ...

# %%
studentNorthWesternRegion.value_counts().sum()
# Out:
# 2901

# %%
#From all the 2901 students from North Western Region, we can see that 704 have failed their module presentations. That way we see that 24,2% of the students failed.

# %%
#South East Region
studentSouthEastRegion = studentInfo[studentInfo["region"] == 'South East Region']
studentSouthEastRegion.value_counts().sum()
# Out:
# 2111

# %%
studentSouthEastRegionFail = studentInfo[(studentInfo['final_result']=='Fail') & (studentInfo['region']=='South East Region')]
studentSouthEastRegionFail.head()
# Out:
#      code_module code_presentation  id_student gender             region  \
# 129          AAA             2013J      295741      M  South East Region
# 425          AAA             2014J      139033      M  South East Region
# 874          BBB             2013B      247267      M  South East Region
# 961          BBB             2013B      335910      F  South East Region
# 1006         BBB             2013B      365439      F  South East Region
#
#           highest_education imd_band age_band  num_of_prev_attempts  \
# 129   A Level or Equivalent   40-50%    35-55                     0
# 425   A Level or Equivalent  90-100%    35-55                     0
# 874      Lower Than A Level   70-80%     0-35                     0
# 961   A Level or Equivalent   30-40%     0-35                     0
# 1006       HE Qualification   60-70%     0-35                     0
#
#       studied_credits disability final_result
# 129               240          N         Fail
# ...

# %%
studentSouthEastRegionFail.value_counts().sum()
# Out:
# 375

# %%
df = pd.DataFrame({'region': ['Wales','Wales', 'North Western Region','North Western Region', 'South East Region','South East Region'],
                   'numberStudents': [1466,620,2197, 704,
                                 1736,375],
                   'Time': ['P', 'F', 'P', 'F', 'P',
                            'F']})

# %%
sns.set_theme(style="whitegrid")



#Doing a Graph to confront the number of students that pass and fail 
g = sns.barplot(
    x="region", y="numberStudents", hue="Time",
    data = df
)

# %%
#As we can see, on this region from the 2111 students that were from South East Region, only 375 failed their final results. Wich means that only 17% had a bad grade.
#Comparing those 3 regions, we can see that statistically the students from Wales have more tendency to fail their module presentations, since almost 30% of the student have failed. With this information, we get the conclusion that the region of Wales has to improve their method of learning, to see if this results change somehow for better.

# %%
#Another way of tracking this data is analyzing another condition that may affected the students final results - the age band. Knowing the age there has a maior percentage of failness, teachers can focus on them and provide a new method of learning so they can improve their final results on module presentation.

# %%
studentAge = studentInfo["age_band"]
studentAge.value_counts()
# Out:
# 0-35       20665
# 35-55       8298
# Unknown     3446
# 55<=         184
# Name: age_band, dtype: int64

# %%
#Looking at this output we can understand that the majority of the students are between the ages from 0 to 35 with 20665. The other ages bands only have 8298 on 35-55 and higher than 55 only 184.

# %%
studentAgeFailBetween035 = studentInfo[(studentInfo['final_result']=='Fail') & (studentInfo['age_band']=='0-35')]
studentAgeFailBetween035
# Out:
#       code_module code_presentation  id_student gender                region  \
# 52            AAA             2013J      146188      F  West Midlands Region
# 53            AAA             2013J      147756      M          North Region
# 70            AAA             2013J      175991      F  North Western Region
# 76            AAA             2013J      185439      M         London Region
# 86            AAA             2013J      205719      M   East Anglian Region
# ...           ...               ...         ...    ...                   ...
# 32534         GGG             2014J      696711      F                 Wales
# 32542         GGG             2014J      697456      M  North Western Region
# 32544         GGG             2014J      698019      F                 Wales
# 32581         GGG             2014J     2456431      F          South Region
# 32588         GGG             2014J     2640965      F                 Wales
#
# ...

# %%
studentAgeFailBetween035.value_counts().sum()
# Out:
# 4540

# %%
#As we can see from the students there they age stands between 0 and 35, only 4540 failed their module presentation.

# %%
studentAgeFailBetween3555 = studentInfo[(studentInfo['final_result']=='Fail') & (studentInfo['age_band']=='35-55')]
studentAgeFailBetween3555
# Out:
#       code_module code_presentation  id_student gender                region  \
# 18            AAA             2013J       74372      M   East Anglian Region
# 100           AAA             2013J      241729      F  East Midlands Region
# 111           AAA             2013J      268073      M   East Anglian Region
# 117           AAA             2013J      281250      M                 Wales
# 129           AAA             2013J      295741      M     South East Region
# ...           ...               ...         ...    ...                   ...
# 32550         GGG             2014J      699628      F                 Wales
# 32559         GGG             2014J     1890660      F          North Region
# 32562         GGG             2014J     1931810      F         London Region
# 32580         GGG             2014J     2378591      F  West Midlands Region
# 32582         GGG             2014J     2475886      F   East Anglian Region
#
# ...

# %%
studentAgeFailBetween3555.value_counts().sum()
# Out:
# 1494

# %%
#From all the people that have age between 35 and 55 (8298) we can see that 1494 failed their module exame. (18,0%)

# %%
studentAgeFailAbove55 = studentInfo[(studentInfo['final_result']=='Fail') & (studentInfo['age_band']=='55<=')]
studentAgeFailAbove55
# Out:
#       code_module code_presentation  id_student gender                region  \
# 323           AAA             2013J     2461190      M          South Region
# 639           AAA             2014J      852847      M     South West Region
# 6215          BBB             2014B     1431750      M  West Midlands Region
# 8612          BBB             2014J     2537934      M   East Anglian Region
# 10438         CCC             2014B     1969407      M   East Anglian Region
# 10529         CCC             2014B     2513997      M         London Region
# 10735         CCC             2014J      264845      F  West Midlands Region
# 10792         CCC             2014J      322907      M         London Region
# 11227         CCC             2014J      539451      M         London Region
# 12858         CCC             2014J     1478030      M         London Region
# 13639         DDD             2013B      503731      M     South West Region
# ...

# %%
studentAgeFailAbove55.value_counts().sum()
# Out:
# 24

# %%
df = pd.DataFrame({'age_band': ['0-35','0-35', '35-55','35-55', '55>=','55>='],
                   'numberStudents': [16125,4540,6804, 1494,
                                 160,24],
                   'Time': ['P', 'F', 'P', 'F', 'P',
                            'F']})

# %%
sns.set_theme(style="whitegrid")



#Doing a Graph to confront the number of students that pass and fail 
g = sns.barplot(
    x="age_band", y="numberStudents", hue="Time",
    data = df
)

# %%
#In this age band, we have less people registred but still 24 people failed their module presentation. (13%)
#Even though there are a lot of missing values on this column, this information could be very useful. As we can see, the age could be a very important statement once you are learning, every course have a lot of different people with different ages, that need a different kind of help when teaching. Even on the age band between 0-35,that are on regular time of school, they have a rate of failure of 21,9%. That way the lectures can see if they can improve their method of lecturing and change this numbers to have better results on the module presentations.

# %%
#If we can see that from the age band how many times the students have repeat their module presentations, that way we can see if even when the students passed, how many attemps they have to do to get good grades.

# %%
studentAgeAttemps = studentInfo.groupby("age_band")["num_of_prev_attempts"].describe()
studentAgeAttemps
# Out:
#             count      mean       std  min  25%  50%  75%  max
# age_band
# 0-35      20665.0  0.158771  0.468215  0.0  0.0  0.0  0.0  6.0
# 35-55      8298.0  0.173777  0.506605  0.0  0.0  0.0  0.0  6.0
# 55<=        184.0  0.108696  0.329149  0.0  0.0  0.0  0.0  2.0
# Unknown    3446.0  0.167441  0.487994  0.0  0.0  0.0  0.0  5.0

# %%
studentAgeNumAttemps = studentInfo[(studentInfo['num_of_prev_attempts']>= 1)]
studentAgeNumAttemps
# Out:
#       code_module code_presentation  id_student gender                region  \
# 395           AAA             2014J       65002      F   East Anglian Region
# 403           AAA             2014J       94961      M          South Region
# 412           AAA             2014J      121349      F     South West Region
# 415           AAA             2014J      129955      M  West Midlands Region
# 422           AAA             2014J      135335      F   East Anglian Region
# ...           ...               ...         ...    ...                   ...
# 32007         GGG             2014J      629258      F         London Region
# 32008         GGG             2014J      631446      F   East Anglian Region
# 32017         GGG             2014J      633561      F      Yorkshire Region
# 32567         GGG             2014J     2053521      F     South West Region
# 32580         GGG             2014J     2378591      F  West Midlands Region
#
# ...

# %%
studentAgeNumAttemps.value_counts().sum()
# Out:
# 3605

# %%
#How many times do students have repeat their assignments?
studentAgeNumAttemps035 = studentInfo[(studentInfo['num_of_prev_attempts']>= 1) & (studentInfo['age_band']=='0-35')]
studentAgeNumAttemps035
# Out:
#       code_module code_presentation  id_student gender                region  \
# 395           AAA             2014J       65002      F   East Anglian Region
# 415           AAA             2014J      129955      M  West Midlands Region
# 422           AAA             2014J      135335      F   East Anglian Region
# 426           AAA             2014J      141377      M     South West Region
# 429           AAA             2014J      147756      M          North Region
# ...           ...               ...         ...    ...                   ...
# 31985         GGG             2014J      620239      F  North Western Region
# 31988         GGG             2014J      622118      F     South West Region
# 32002         GGG             2014J      627809      F   East Anglian Region
# 32003         GGG             2014J      627812      F      Yorkshire Region
# 32017         GGG             2014J      633561      F      Yorkshire Region
#
# ...

# %%
#How many students from the age 0-35 have done their assessments more than 1 time?
studentAgeNumAttemps035.value_counts().sum()
# Out:
# 2527

# %%
#How many students from the age 35-55 have done their assessments more than 1 time?
studentAgeNumAttemps3555 = studentInfo[(studentInfo['num_of_prev_attempts']>= 1) & (studentInfo['age_band']=='35-55')]
studentAgeNumAttemps3555.value_counts().sum()
# Out:
# 1061

# %%
#How many students from of 55 have done their assessments more than 1 time?
studentAgeNumAttemps55 = studentInfo[(studentInfo['num_of_prev_attempts']>= 1) & (studentInfo['age_band']=='55>=')]
studentAgeNumAttemps55.value_counts().sum()
# Out:
# 0

# %%
#This information show us that the students above the age of 55 didn't repeat their assessments more than 1 time. Wich could mean that people around that age are more prepared for the assessments. Normally when people with 55 or mre decided to study, tend to be more focused and this could be an explaination of why the number are like this.

# %% [markdown]
# ### Student Registration

# %%
studentRegistration = pd.read_csv('studentRegistration.csv')
studentRegistration.head()
# Out:
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       28400              -53.0
# 2         AAA             2013J       30268              -92.0
# 3         AAA             2013J       31604              -52.0
# 4         AAA             2013J       32885             -176.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                 12.0
# 3                  NaN
# 4                  NaN

# %%
#How many registrations do the modules have? 
studentModuleDate = studentRegistration.groupby("code_module")["date_registration"].count()
studentModuleDate.head()
# Out:
# code_module
# AAA     748
# BBB    7900
# CCC    4426
# DDD    6257
# EEE    2932
# Name: date_registration, dtype: int64

# %%
#Confronting this two variables, we can see how many registration the courses have. It this data we can see wich course more engagement for the students since the date of registration express the real date on the module presentation. COnclusion, the module "BBB" have a lot more registrations than the others.

# %% [markdown]
# ### Student Vle

# %%
studentVle = pd.read_csv('studentVle.csv')
studentVle.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
#How many times students interact with the materials per course?
studentCourseCLick = studentVle.groupby("code_module")["sum_click"].count()
studentCourseCLick
# Out:
# code_module
# AAA     350298
# BBB    1567564
# CCC    1207827
# DDD    2166486
# EEE     961433
# FFF    4014499
# GGG     387173
# Name: sum_click, dtype: int64

# %%
studentVleCLick = studentVle[(studentVle['code_module']== 'AAA') & (studentVle['sum_click'])]
studentVleCLick
# Out:
#        code_module code_presentation  id_student  id_site  date  sum_click
# 1              AAA             2013J       28400   546652   -10          1
# 2              AAA             2013J       28400   546652   -10          1
# 3              AAA             2013J       28400   546614   -10         11
# 4              AAA             2013J       28400   546714   -10          1
# 7              AAA             2013J       28400   546688   -10         15
# ...            ...               ...         ...      ...   ...        ...
# 350292         AAA             2014J      331358   877030   269          1
# 350293         AAA             2014J      335764   877025   269          1
# 350295         AAA             2014J      332884   877030   269          1
# 350296         AAA             2014J      332884   877399   269          1
# 350297         AAA             2014J      332884   877134   269          1
#
# [217032 rows x 6 columns]

# %%
#Right now I'm going to confront the data between the course the students are taken and how many times they interact with the system, so we can see what course take more effort than the others. I'm assuming that the inteacts of the materials would represent the difficult of the course, since it takes a lot of interectiin of the students, so it might represent the effort they are taking to make the
#AAA
codeAAndCLick = studentVle[(studentVle['code_module']== 'AAA') & (studentVle['sum_click']>= 1 )]
codeAAndCLick.value_counts().sum()
# Out:
# 350298

# %%
#As we can see the code module AAAA have 350290 interacts with the material on the VLE.

# %%
#BBB
codeBAndCLick = studentVle[(studentVle['code_module']== 'BBB') & (studentVle['sum_click']>= 1 )]
codeBAndCLick.value_counts().sum()
# Out:
# 1567564

# %%
#As we can see, the code module B takes a lot a effort and the students interact way more than the A, since it has 1.567.564 interacts.

# %%
#DDD
codeDAndCLick = studentVle[(studentVle['code_module']== 'DDD') & (studentVle['sum_click']>= 1 )]
codeDAndCLick.value_counts().sum()
# Out:
# 2166486

# %%
#As we can see the values here are even less than the A, so we can assume that the students make less effort on this course than the others.

# %% [markdown]
# ### Vle

# %%
vle = pd.read_csv('vle.csv')
vle.head()
# Out:
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %%
#How many activity exists of wich type?
activityType = vle["activity_type"].value_counts()
activityType
# Out:
# resource          2660
# subpage           1055
# oucontent          996
# url                886
# forumng            194
# quiz               127
# page               102
# oucollaborate       82
# questionnaire       61
# ouwiki              49
# dataplus            28
# externalquiz        26
# homepage            22
# ouelluminate        21
# glossary            21
# dualpane            20
# repeatactivity       5
# htmlactivity         4
# sharedsubpage        3
# folder               2
# Name: activity_type, dtype: int64

# %%
activityTypePerCourse = vle[(vle['code_module']== "BBB") & (vle['activity_type'] == 'resource' )]
activityTypePerCourse.value_counts().sum()
# Out:
# 88

# %%
#Doing this command i'm confronting the code module "BBB" with the type of activity "resource" since its the most used by the students. This way we can see that 88 of the students have used this type once they are on the course with the module "BBB".
